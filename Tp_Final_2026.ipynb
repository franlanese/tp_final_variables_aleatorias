# %% [markdown]
# <div align="center">
#
# <img src="./logo_ips_unr.png" alt="Logo UNR" width="150">
#
# <br><br><br><br>
#
# # UNIVERSIDAD NACIONAL DE ROSARIO
# ### Instituto Politécnico General San Martín (IPS) – AUS
#
# <br><br><br>
#
# ## Probabilidad y Estadística
#
# ### Trabajo Práctico Grupal: Variables Aleatorias <br> (Unidades III y IV)
#
# <br><br><br>
#
# **Docente:** Alejandra Zorzi
#
# <br>
#
# **Integrantes:**
# Franco Sorice
# Franco Lanese
#
# <br>
#
# **Fecha:** 6 de agosto de 2026
#
# <br><br><br><br>
#
# ---
#
# **Rosario, 2026**
#
# </div>

# %% [markdown]
# <h1>Seleccion de Datos y Definición de Variables</h1>

# %% [markdown]
# ## Dataset seleccionado
#
# Se utilizará un dataset de videojuegos de la plataforma **Steam**, el cual contiene información sobre miles de juegos, incluyendo nombre, desarrollador, género, cantidad de logros (*Achievements*), tiempo promedio de juego (*Average Playtime*), precio, entre otras características.
#
# Para el desarrollo del trabajo se utilizará un conjunto de datos conformado por **27075** juegos, superando ampliamente el mínimo de **1000 registros** establecido por la consigna.

# %%
# %run scripts/dataset.py

# %% [markdown]
# ## Variable aleatoria discreta
#
# Sea la variable aleatoria discreta
#
# $$
# X=\text{Edad mínima requerida (Required Age)}
# $$
#
# La variable \(X\) representa la edad mínima requerida para ejecutar un videojuego de Steam.
#
#
# Se trata de una **variable aleatoria discreta**, ya que únicamente puede asumir un conjunto finito de valores enteros. No existen valores intermedios ni fraccionarios dentro del dataset.

# %%
# %run scripts//valores.py
# Out:
# Valores posibles:
# [0, 3, 7, 12, 16, 18]

# %% [markdown]
# ## Variable aleatoria continua
#
# Sea la variable aleatoria continua
#
# $$
# Y=\text{Precio del juego (Price)}
# $$
#
# La variable \(Y\) representa el precio de cada videojuego.
#
# Se considera una **variable aleatoria continua**, ya que puede tomar distintos valores dentro de un intervalo, incluyendo valores decimales (por ejemplo, 3.99, 7.19 o 19.99).
#
# Aunque en el dataset los precios se registran con dos cifras decimales, desde el punto de vista estadístico se modelan como una variable continua.

# %% [markdown]
# # Variable discreta: Edad Requerida (X)
#
# **Variable:** X = Edad requerida (Required Age)
#
#
# ## I. Recorrido de X:
#
# Los valores posibles de la Variable Discreta elegida son:
#
# $$
# Rx = {0, 3, 7, 12, 16, 18}
# $$

# %% [markdown]
# ## II. Tabla de frecuencias y cálculo de función de probabilidad puntual

# %% [markdown]
# ## I. Construcción de la tabla de frecuencias
#
# Sea \(X\) la variable aleatoria discreta que representa la **edad mínima requerida** (*Required Age*) para jugar un videojuego del dataset de Steam.
#
# Para construir la tabla de frecuencias se siguieron los siguientes pasos.
#
# ### Paso 1 — Identificar los valores posibles
#
# Se analizaron los **27075** registros del dataset y se identificaron todos los valores distintos que puede tomar la variable.
#
# $$
# R_X=\{0,3,7,12,16,18\}
# $$
#
# ### Paso 2 — Calcular la frecuencia absoluta
#
# Para cada valor del recorrido se contó la cantidad de juegos que poseen esa edad mínima requerida. A esta cantidad se la denomina **frecuencia absoluta** y se representa mediante: f<sub>i</sub>
#
# ### Paso 3 — Calcular la probabilidad puntual
#
# La probabilidad asociada a cada valor de la variable se obtuvo dividiendo la frecuencia absoluta entre el número total de registros del dataset.
#
# $$p_X(x)=P(X=x)=\frac{f_i}{N}$$
#
# donde:
#
# - \(f<sub>i</sub>\) es la frecuencia absoluta.
# - \(N = 27075\) es la cantidad total de observaciones.
#
# **Paso 1 — Para \(x=0\):**
#
# La frecuencia absoluta es \(f<sub>i</sub>=26479\).
#
# $$
# P(X=0)=\frac{26479}{27075}
# $$
#
# $$
# P(X=0)=0.977987
# $$
#
#
# **Paso 2 — Para \(x=3\):**
#
# La frecuencia absoluta es \(f<sub>i</sub>=11\).
#
# $$
# P(X=3)=\frac{11}{27075}
# $$
#
# $$
# P(X=3)=0.000406
# $$
#
#
# **Paso 3 — Para \(x=7\):**
#
# La frecuencia absoluta es \(f<sub>i</sub>=12\).
#
# $$
# P(X=7)=\frac{12}{27075}
# $$
#
# $$
# P(X=7)=0.000443
# $$
#
#
# **Paso 4 — Para \(x=12\):**
#
# La frecuencia absoluta es \(f<sub>i</sub>=73\).
#
# $$
# P(X=12)=\frac{73}{27075}
# $$
#
# $$
# P(X=12)=0.002696
# $$
#
#
# **Paso 5 — Para \(x=16\):**
#
# La frecuencia absoluta es \(f<sub>i</sub>=192\).
#
# $$
# P(X=16)=\frac{192}{27075}
# $$
#
# $$
# P(X=16)=0.007091
# $$
#
#
# **Paso 6 — Para \(x=18\):**
#
# La frecuencia absoluta es \(f<sub>i</sub>=308\).
#
# $$
# P(X=18)=\frac{308}{27075}
# $$
#
# $$
# P(X=18)=0.011376
# $$
#
# De esta manera se obtiene la función de probabilidad puntual de la variable aleatoria discreta, cuyos valores se resumen en la siguiente tabla.
#
# El siguiente script construye la tabla de frecuencias y calcula automáticamente la función de probabilidad puntual.

# %%
# %run scripts/tabla_frecuencias.py
# Out:
# <style type="text/css">
# #T_062de_row0_col2 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_062de_row1_col2, #T_062de_row2_col2, #T_062de_row3_col2 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_062de_row4_col2 {
#   background-color: #f6faff;
#   color: #000000;
# }
# #T_062de_row5_col2 {
#   background-color: #f5fafe;
#   color: #000000;
# }
# </style>
# <table id="T_062de">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_062de_level0_col0" class="col_heading level0 col0" >x (Edad mínima)</th>
#       <th id="T_062de_level0_col1" class="col_heading level0 col1" >fi</th>
#       <th id="T_062de_level0_col2" class="col_heading level0 col2" >p(x) = P(X = x)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_062de_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_062de_row0_col0" class="data row0 col0" >0</td>
# ...

# %% [markdown]
# A partir de la tabla obtenida se observa que la gran mayoría de los videojuegos (**97,80 %**) poseen una edad mínima requerida de **0 años**, mientras que los restantes valores (3, 7, 12, 16 y 18 años) presentan frecuencias considerablemente menores.

# %% [markdown]
# ## III. Diagrama de barras de px(x)

# %% [markdown]
# El siguiente script construye el diagrama de barras del cálculo de probabilidad puntual realizado anteriormente.

# %%
# %run scripts/funcion_probabilidad.py

# %% [markdown]
# ## Observación
#
#
# Con fines únicamente ilustrativos, se presenta la distribución excluyendo el valor 0, ya que concentra el 97,8 % de los registros e impide apreciar las probabilidades del resto de los valores. De aquí en adelante, todos los cálculos de estadística y probabilidad serán evaluados tomando los registros en su totalidad, sin la exclusión de los valores "required_age" iguales a cero.

# %% [markdown]
# ## Tabla de frecuencias y probabilidades (con valores 0 excluidos)

# %%
# %run scripts/tabla_frecuencias_limit.py
# Out:
# <style type="text/css">
# #T_8e3a3_row0_col2, #T_8e3a3_row1_col2 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_8e3a3_row2_col2 {
#   background-color: #cee0f2;
#   color: #000000;
# }
# #T_8e3a3_row3_col2 {
#   background-color: #4695c8;
#   color: #f1f1f1;
# }
# #T_8e3a3_row4_col2 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_8e3a3">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8e3a3_level0_col0" class="col_heading level0 col0" >x (Edad mínima)</th>
#       <th id="T_8e3a3_level0_col1" class="col_heading level0 col1" >fi</th>
#       <th id="T_8e3a3_level0_col2" class="col_heading level0 col2" >p(x) = P(X = x)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8e3a3_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_8e3a3_row0_col0" class="data row0 col0" >3</td>
#       <td id="T_8e3a3_row0_col1" class="data row0 col1" >11</td>
# ...

# %% [markdown]
# ## Función de probabilidad puntual (con valores 0 excluidos)

# %%
# %run scripts/funcion_probabilidad_limit.py

# %% [markdown]
# ## IV. Cálculos

# %% [markdown]
# ### E[X] (Esperanza)

# %% [markdown]
# La esperanza matemática de una variable aleatoria discreta se calcula como:
#
# $$
# E[X] = \sum x \cdot p(x)
# $$
#
# Aplicando esto a nuestra variable:
#
# $$
# E[X] = 0 \times P(X=0) + 3 \times P(X=3) + 7 \times P(X=7) + 12 \times P(X=12) + 16 \times P(X=16) + 18 \times P(X=18)
# $$
#
# Sustituyendo los valores de probabilidad obtenidos en la tabla:
#
# $$
# E[X] = 0 \times 0.977987 + 3 \times 0.000406 + 7 \times 0.000443 + 12 \times 0.002696 + 16 \times 0.007091 + 18 \times 0.011376
# $$
#
# **Paso 1 — Término para $x=0$:** como está multiplicado por 0, este término se anula:
#
# $$
# 0 \times 0.977987 = 0
# $$
#
# **Paso 2 — Término para $x=3$:**
#
# $$
# 3 \times 0.000406 = 0.001218
# $$
#
# **Paso 3 — Término para $x=7$:**
#
# $$
# 7 \times 0.000443 = 0.003101
# $$
#
# **Paso 4 — Término para $x=12$:**
#
# $$
# 12 \times 0.002696 = 0.032352
# $$
#
# **Paso 5 — Término para $x=16$:**
#
# $$
# 16 \times 0.007091 = 0.113456
# $$
#
# **Paso 6 — Término para $x=18$:**
#
# $$
# 18 \times 0.011376 = 0.204768
# $$
#
# **Paso 7 — Sumar todos los términos:**
#
# $$
# E[X] = 0 + 0.001218 + 0.003101 + 0.032352 + 0.113456 + 0.204768
# $$
#
# $$
# E[X] = 0.354895
# $$
#
# Por lo tanto, la **edad mínima requerida promedio** es de aproximadamente **0.355 años**, lo cual es esperable dado que la gran mayoría de los juegos no tienen restricción de edad (el 97.8% tiene edad requerida 0).

# %% [markdown]
# ### Cálculo de E[X²]
#
# Para calcular la varianza, primero necesitamos el segundo momento $E[X^2]$:
#
# $$
# E[X^2] = \sum x^2 \cdot p(x)
# $$
#
# Desarrollando:
#
# $$
# E[X^2] = 0^2 \times P(X=0) + 3^2 \times P(X=3) + 7^2 \times P(X=7) + 12^2 \times P(X=12) + 16^2 \times P(X=16) + 18^2 \times P(X=18)
# $$
#
# Sustituyendo los valores:
#
# $$
# E[X^2] = 0 \times 0.977987 + 9 \times 0.000406 + 49 \times 0.000443 + 144 \times 0.002696 + 256 \times 0.007091 + 324 \times 0.011376
# $$
#
# **Paso 1 — Término para $x=0$:**
#
# $$
# 0^2 \times 0.977987 = 0
# $$
#
# **Paso 2 — Término para $x=3$:**
#
# $$
# 3^2 \times 0.000406 = 9 \times 0.000406 = 0.003654
# $$
#
# **Paso 3 — Término para $x=7$:**
#
# $$
# 7^2 \times 0.000443 = 49 \times 0.000443 = 0.021707
# $$
#
# **Paso 4 — Término para $x=12$:**
#
# $$
# 12^2 \times 0.002696 = 144 \times 0.002696 = 0.388224
# $$
#
# **Paso 5 — Término para $x=16$:**
#
# $$
# 16^2 \times 0.007091 = 256 \times 0.007091 = 1.815296
# $$
#
# **Paso 6 — Término para $x=18$:**
#
# $$
# 18^2 \times 0.011376 = 324 \times 0.011376 = 2.912256
# $$
#
# **Paso 7 — Sumar todos los términos:**
#
# $$
# E[X^2] = 0 + 0.003654 + 0.021707 + 0.388224 + 1.815296 + 2.912256
# $$
#
# $$
# E[X^2] = 5.915705
# $$

# %% [markdown]
# ### Cálculo de Var(X) (Varianza)
#
# La varianza se calcula mediante la fórmula:
#
# $$
# Var(X) = E[X^2] - (E[X])^2
# $$
#
# **Paso 1 — Identificar los valores obtenidos:**
#
# $$
# E[X^2] = 5.915705
# $$
#
# $$
# E[X] = 0.354895
# $$
#
# **Paso 2 — Calcular $(E[X])^2$:**
#
# $$
# (E[X])^2 = (0.354895)^2 = 0.125951
# $$
#
# **Paso 3 — Aplicar la fórmula:**
#
# $$
# Var(X) = 5.915705 - 0.125951
# $$
#
# $$
# Var(X) = 5.789754
# $$
#
#
#
# Por lo tanto, la **varianza** de la edad mínima requerida es de **5.789754**.

# %% [markdown]
# # V. Construir y graficar la Función de Distribución Acumulada
#
# La función de distribución acumulada de una variable aleatoria discreta se define como la probabilidad de que la variable tome un valor **menor o igual** que un determinado valor \(x\).
#
# $$
# F_X(x)=P(X\le x)
# $$
#
# Para calcularla, se acumulan las probabilidades obtenidas en la función de probabilidad puntual.
#
# ### Paso 1 — Para \(x=0\)
#
# Como no existen valores menores que 0 en el recorrido de la variable:
#
# $$
# F_X(0)=P(X\le0)=P(X=0)
# $$
#
# $$
# F_X(0)=0.977987
# $$
#
#
# ### Paso 2 — Para \(x=3\)
#
# Se acumulan las probabilidades correspondientes a los valores 0 y 3.
#
# $$
# F_X(3)=P(X\le3)
# $$
#
# $$
# F_X(3)=P(X=0)+P(X=3)
# $$
#
# $$
# F_X(3)=0.977987+0.000406
# $$
#
# $$
# F_X(3)=0.978393
# $$
#
#
# ### Paso 3 — Para \(x=7\)
#
# $$
# F_X(7)=P(X\le7)
# $$
#
# $$
# F_X(7)=P(X=0)+P(X=3)+P(X=7)
# $$
#
# $$
# F_X(7)=0.977987+0.000406+0.000443
# $$
#
# $$
# F_X(7)=0.978836
# $$
#
#
# ### Paso 4 — Para \(x=12\)
#
# $$
# F_X(12)=P(X\le12)
# $$
#
# $$
# F_X(12)=P(X=0)+P(X=3)+P(X=7)+P(X=12)
# $$
#
# $$
# F_X(12)=0.977987+0.000406+0.000443+0.002696
# $$
#
# $$
# F_X(12)=0.981532
# $$
#
#
# ### Paso 5 — Para \(x=16\)
#
# $$
# F_X(16)=P(X\le16)
# $$
#
# $$
# F_X(16)=P(X=0)+P(X=3)+P(X=7)+P(X=12)+P(X=16)
# $$
#
# $$
# F_X(16)=0.977987+0.000406+0.000443+0.002696+0.007091
# $$
#
# $$
# F_X(16)=0.988623
# $$
#
#
# ### Paso 6 — Para \(x=18\)
#
# $$
# F_X(18)=P(X\le18)
# $$
#
# $$
# F_X(18)=P(X=0)+P(X=3)+P(X=7)+P(X=12)+P(X=16)+P(X=18)
# $$
#
# $$
# F_X(18)=0.977987+0.000406+0.000443+0.002696+0.007091+0.011376
# $$
#
# $$
# F_X(18)=0.999999\approx1
# $$
#
# Debido al redondeo de las probabilidades a seis cifras decimales, el valor final resulta ligeramente inferior a 1. Utilizando las probabilidades con toda su precisión, se obtiene exactamente:
#
# $$
# F_X(18)=1
# $$
#
# El siguiente script construye la función de distribución acumulada y genera su representación gráfica mediante un gráfico escalonado.

# %%
# %run scripts/funcion_distribucion_acumulada.py

# %% [markdown]
# # VI. Construir y graficar la Función de Distribución Acumulada

# %% [markdown]
# ## Análisis de la distribución de la variable `required_age`
#
# Al observar la función de probabilidad puntual de la variable edad mínima requerida (`required_age`), se aprecia que la mayor parte de la probabilidad se concentra en el valor **0**, ya que aproximadamente el **97.8 %** de los juegos no poseen una restricción de edad. Como consecuencia, la distribución presenta un pico muy pronunciado en dicho valor y probabilidades muy pequeñas para el resto de los valores (3, 7, 12, 16 y 18).
#
# ### Comparación con distribuciones teóricas
#
# - **Distribución Binomial:**
#   No presenta una forma de campana ni una distribución aproximadamente simétrica, por lo que no se asemeja a una distribución binomial.
#
# - **Distribución de Poisson:**
#   Aunque el valor de mayor probabilidad corresponde al menor valor de la variable, la distribución no presenta un decaimiento suave y progresivo, por lo que no puede considerarse similar a una distribución de Poisson.
#
# - **Distribución Geométrica:**
#   La distribución comparte con la geométrica el hecho de concentrar la mayor probabilidad en el primer valor. Sin embargo, las probabilidades posteriores no decrecen de forma monótona, sino que presentan pequeños incrementos entre algunos valores, por lo que tampoco se ajustan visualmente a una distribución geométrica.
#
# ### Conclusión
#
# La distribución de la variable `required_age` **no presenta una similitud visual clara** con ninguna de las distribuciones notables analizadas (Binomial, Poisson o Geométrica). Esto se debe a que la gran mayoría de los juegos del dataset tienen una edad mínima requerida de 0 años, generando una distribución altamente concentrada en un único valor.

# %% [markdown]
# <h1>Variable Continua: Precio (Y)</h1>

# %% [markdown]
# ## I. Histograma
# Agruparemos los resultados en intervalos utilizando la **Regla de Sturges**:

# %% [markdown]
# $$
# {\text{k} = \left[1 + 3,322\log_{10}{n}\right]}
# $$

# %%
# %run scripts/histograma.py
# Out:
# Cantidad de datos (n): 24485
# Intervalos calculados (k): 16

# %% [markdown]
# ## II. Identificación visual
#
# Podemos observar que las barras tienen un breve crecimiento en el segundo intervalo, pero luego **decrecen rápidamente**. Si bien esto se aleja levemente de una Exponencial pura (que debería decaer monótonamente desde el primer intervalo), la tendencia dominante es de caída rápida, lo cual es consistente con este modelo. Esto se debe a que la mayoría de los juegos en Steam son títulos económicos (indies, juegos pequeños), mientras que muy pocos alcanzan precios elevados (ediciones AAA o de colección). Por lo tanto, conviene elegir el modelo **Exponencial**.

# %% [markdown]
# ### III. Parametrización
#
# Al identificar en la Fase 2 que el precio de los juegos se comporta como una variable **Exponencial**, necesitamos saber el parámetro $\lambda$ (tasa) que define la curva específica de nuestro modelo:
#
# $$
# f_Y(y) = \lambda\, e^{-\lambda y}, \quad y \ge 0
# $$
#
# Usamos el método de los momentos: la Exponencial tiene una media teórica igual a $1/\lambda$. Igualando esa media teórica con la media muestral $\bar y$ de nuestros datos y despejando:
#
# $$
# \lambda = \frac{1}{\bar y}
# $$
#
# El siguiente script calcula $\lambda$ a partir de los datos y reemplaza su valor en el modelo para obtener la curva específica:

# %%
# %run scripts/parametrizacion.py
# Out:
# $\displaystyle \bar y = \frac{\sum y_i}{n} = \frac{161065.38}{24485} = 6.5781$
# Media muestral: 6.5781
# $\displaystyle \lambda = \frac{1}{\bar y} = \frac{1}{6.5781} = 0.1520$
# Lambda estimado: 0.1520
# $\displaystyle f_Y(y) = 0.1520\,e^{-0.1520\,y}, \quad y \ge 0$

# %% [markdown]
# Esta curva la usaremos en la Fase 4 para calcular probabilidades.

# %% [markdown]
# ## IV. Cálculos guiados
#
# ### Verificación de normalización
#
# Para que $f_Y(y)$ sea una función de densidad válida, **el área total bajo la curva debe ser igual a 1**:
#
# $$
# \int_0^{\infty} f_Y(y)\,dy = \int_0^{\infty} \lambda e^{-\lambda y}\,dy
# $$
#
# **Paso 1 — Regla del múltiplo constante:** como $\lambda$ es una constante (no depende de $y$), se puede sacar fuera de la integral:
#
# $$
# \int_0^{\infty} \lambda e^{-\lambda y}\,dy = \lambda \int_0^{\infty} e^{-\lambda y}\,dy
# $$
#
# **Paso 2 — Regla de la exponencial:** para integrar una exponencial de la forma $e^{ky}$ (con $k$ constante), se usa la regla general
#
# $$
# \int e^{ky}\,dy = \frac{1}{k}e^{ky} + C
# $$
#
# En nuestro caso $k=-\lambda$, entonces:
#
# $$
# \int e^{-\lambda y}\,dy = \frac{1}{-\lambda}e^{-\lambda y} + C = -\frac{1}{\lambda}e^{-\lambda y} + C
# $$
#
# **Paso 3 — Combinar ambos pasos:** multiplicamos ese resultado por el $\lambda$ que habíamos sacado en el Paso 1 (se cancela con el $1/\lambda$):
#
# $$
# \lambda \cdot \left(-\frac{1}{\lambda}e^{-\lambda y}\right) = -e^{-\lambda y}
# $$
#
# Esa es la antiderivada de $f_Y(y)$. Ahora la evaluamos entre los límites 0 e infinito:
#
# $$
# \Big[-e^{-\lambda y}\Big]_0^{\infty} = \lim_{y\to\infty}\left(-e^{-\lambda y}\right) - \left(-e^{-\lambda \cdot 0}\right)
# $$
#
# - Cuando $y\to\infty$: como $\lambda>0$, el exponente $-\lambda y \to -\infty$, entonces $e^{-\lambda y}\to 0$. Ese término vale $0$.
# - Cuando $y=0$: $e^{-\lambda \cdot 0} = e^0 = 1$, entonces ese término vale $-(-1) = 1$.
#
# $$
# \Big[-e^{-\lambda y}\Big]_0^{\infty} = 0 - (-1) = 1
# $$
#
# Por lo tanto, la función de densidad está **correctamente normalizada**.

# %% [markdown]
# ### Función de Distribución Acumulada
#
# Por definición, la función de distribución acumulada es la probabilidad de que $Y$ tome un valor menor o igual a $y$, es decir, el área bajo $f_Y$ desde 0 hasta $y$:
#
# $$
# F_Y(y) = P(Y \le y) = \int_0^{y} f_Y(t)\,dt = \int_0^{y} \lambda e^{-\lambda t}\,dt
# $$
#
# **Paso 1 — Antiderivada:** usando la misma regla de la exponencial que aplicamos en la verificación de normalización, la antiderivada de $\lambda e^{-\lambda t}$ es $-e^{-\lambda t}$:
#
# $$
# \int_0^{y} \lambda e^{-\lambda t}\,dt = \Big[-e^{-\lambda t}\Big]_0^{y}
# $$
#
# **Paso 2 — Evaluar en los límites** (esta vez entre $0$ y $y$, no entre $0$ e infinito):
#
# $$
# \Big[-e^{-\lambda t}\Big]_0^{y} = \left(-e^{-\lambda y}\right) - \left(-e^{-\lambda \cdot 0}\right)
# $$
#
# - En $t=y$: queda $-e^{-\lambda y}$.
# - En $t=0$: $e^{-\lambda \cdot 0} = e^0 = 1$, entonces ese término vale $-(-1) = 1$.
#
# **Paso 3 — Resultado:**
#
# $$
# F_Y(y) = -e^{-\lambda y} + 1 = 1 - e^{-\lambda y}, \quad y \ge 0
# $$
#
# ### Desviación estándar muestral ($s$)
#
# Mide que tan esparcidos estan los datos con respecto al promedio (la media muestral). Se representa con la letra *s* y se calcula como:
#
# $$
# s = \sqrt{\dfrac{1}{n-1}\sum_{i=1}^{n}(y_i - \bar y)^2}
# $$
#
# La usamos junto con $\bar y$ para calcular $P(Y > \bar y + s)$: la probabilidad de que un juego tenga un precio inusualmente alto.
# ### Probabilidades concretas
#
# Usando $F_Y(y)$ calculamos:
#
# $$
# P(Y \le \bar y) = F_Y(\bar y) \qquad\qquad P(Y > \bar y + s) = 1 - F_Y(\bar y + s)
# $$

# %%
# %run scripts/calculos.py
# Out:
# $\displaystyle s = \sqrt{\dfrac{1}{n-1}\sum_{i=1}^{n}(y_i-\bar y)^2} = \sqrt{\dfrac{1023142.29}{24484}} = 6.4644$
# | Parámetro | Valor |
# |---|---|
# | n | 24485 |
# | Media muestral ($\bar y$) | 6.5781 |
# | Desvío estándar muestral ($s$) | 6.4644 |
# | Tasa ($\lambda$) | 0.1520 |
# $\displaystyle P(Y \le \bar y) = F_Y(6.5781) = 0.6321$
# $\displaystyle P(Y > \bar y + s) = 1 - F_Y(6.5781 + 6.4644) = 0.1377$

# %% [markdown]
# En base a esto, concluimos que hay una probabilidad del 63,21% que un juego tenga un precio inferior al promedio y del 13% que un juego tenga un precio mucho mas alto que el promedio (generalmente uno AAA).

# %% [markdown]
# <h1>Interpretación de Resultados para Ambas Variables</h1>

# %% [markdown]
# ## Paso IV.a - Variable Continua $Y$

# %% [markdown]
# Reutilizamos el modelo Exponencial ajustado en el Paso 3 ($\lambda = 1/\bar y$) y evaluamos su función de distribución acumulada en $y = \bar y + s$:
#
# $$
# F_Y(\bar y + s) = 1 - e^{-\lambda(\bar y + s)}
# $$

# %%
# %run scripts/interpretacion_y.py
# Out:
# | Parámetro | Valor |
# |---|---|
# | $\bar y$ | 6.5781 |
# | $s$ | 6.4644 |
# | $\bar y + s$ | 13.0425 |
# | $\lambda$ | 0.1520 |
# $\displaystyle F_Y(\bar y + s) = 1 - e^{-0.1520\,(13.0425)} = 0.8623$
# Porcentaje esperado por debajo de ($\bar y + s$): 86.23%

# %% [markdown]
# ### Conclusion
#
# Según el modelo Exponencial ajustado a los precios de los juegos de Steam, se espera que aproximadamente el **86.23%** de los juegos tengan un precio por debajo de $\bar y + s \approx \$13.04$ (el precio promedio más una desviación estándar). Es decir, el modelo predice que solo alrededor del 13.77% de los juegos superan ese umbral — un resultado consistente con la forma decreciente observada en el histograma: los precios altos son cada vez menos frecuentes.

# %% [markdown]
# # Paso IV.b - Variable Discreta $X$

# %% [markdown]
# Se eligió como valor de referencia
#
# $$
# k=12
# $$
#
# ya que representa una clasificación de edad frecuente en videojuegos y permite conocer qué proporción del catálogo puede ser utilizada por jugadores cuya edad mínima requerida es de **12 años o menos**.
#
# Por definición, la función de distribución acumulada se expresa como:
#
# $$
# F_X(x)=P(X\le x)
# $$
#
# Por lo tanto,
#
# $$
# P(X\le12)=F_X(12)
# $$
#
# Utilizando la función de distribución acumulada construida en el Paso II,
#
# $$
# F_X(12)=P(X=0)+P(X=3)+P(X=7)+P(X=12)
# $$
#
# Sustituyendo las probabilidades puntuales:
#
# $$
# F_X(12)=0.977987+0.000406+0.000443+0.002696
# $$
#
# Realizando la suma:
#
# $$
# F_X(12)=0.981532
# $$
#
# Por lo tanto,
#
# $$
# \boxed{P(X\le12)=0.981532}
# $$
#
# ### Conclusión
#
# Esto significa que aproximadamente el **98,15 %** de los videojuegos del dataset requieren una edad mínima de **12 años o menos**.
#
# En consecuencia, puede concluirse que la gran mayoría de los juegos disponibles en Steam presentan una clasificación apta para un público general o con restricciones de edad relativamente bajas, mientras que solo una pequeña proporción exige una edad mínima superior a los 12 años.

# %% [markdown]
# # Paso IV.c - Reflexión general

# %% [markdown]
# Consideramos que los modelos elegidos representan adecuadamente el comportamiento general de ambas variables. En el caso de la variable discreta (*Required Age*), la función de probabilidad describe correctamente la distribución de las edades mínimas requeridas por los videojuegos. Para la variable continua (*Price*), el modelo exponencial refleja la tendencia general de que la mayoría de los juegos poseen precios bajos y pocos alcanzan valores elevados. Sin embargo, ambos modelos presentan limitaciones, ya que simplifican la realidad y no capturan completamente valores atípicos ni particularidades de la distribución de los datos.
